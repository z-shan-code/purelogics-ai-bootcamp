# %% [markdown]
# ## Principal Component Analysis (Dimentionality Reduction)
# **Principal Component Analysis** is a dimensionality reduction technique used in data science and machine learning. It transforms a high-dimensional dataset into a lower-dimensional one by:
#
# 1. Identifying the principal components (directions of maximum variance)
#
# 2. Projecting the data onto these components
#
# 3. Preserving as much information (variance) as possible

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('Copy of heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# ## 1st Way

# %%
s_dum = pd.get_dummies(df.Sex)
s_dum
# Out:
#          F      M
# 0    False   True
# 1     True  False
# 2    False   True
# 3     True  False
# 4    False   True
# ..     ...    ...
# 913  False   True
# 914  False   True
# 915  False   True
# 916   True  False
# 917  False   True
#
# [918 rows x 2 columns]

# %%
dum_cp = pd.get_dummies(df.ChestPainType)
dum_cp
# Out:
#        ASY    ATA    NAP     TA
# 0    False   True  False  False
# 1    False  False   True  False
# 2    False   True  False  False
# 3     True  False  False  False
# 4    False  False   True  False
# ..     ...    ...    ...    ...
# 913  False  False  False   True
# 914   True  False  False  False
# 915   True  False  False  False
# 916  False   True  False  False
# 917  False  False   True  False
#
# [918 rows x 4 columns]

# %%
rest_dum = pd.get_dummies(df.RestingECG)
rest_dum
# Out:
#        LVH  Normal     ST
# 0    False    True  False
# 1    False    True  False
# 2    False   False   True
# 3    False    True  False
# 4    False    True  False
# ..     ...     ...    ...
# 913  False    True  False
# 914  False    True  False
# 915  False    True  False
# 916   True   False  False
# 917  False    True  False
#
# [918 rows x 3 columns]

# %%
ex_dum = pd.get_dummies(df.ExerciseAngina)
ex_dum
# Out:
#          N      Y
# 0     True  False
# 1     True  False
# 2     True  False
# 3    False   True
# 4     True  False
# ..     ...    ...
# 913   True  False
# 914   True  False
# 915  False   True
# 916   True  False
# 917   True  False
#
# [918 rows x 2 columns]

# %%
st_dum = pd.get_dummies(df.ST_Slope)
st_dum
# Out:
#       Down   Flat     Up
# 0    False  False   True
# 1    False   True  False
# 2    False  False   True
# 3    False   True  False
# 4    False  False   True
# ..     ...    ...    ...
# 913  False   True  False
# 914  False   True  False
# 915  False   True  False
# 916  False   True  False
# 917  False  False   True
#
# [918 rows x 3 columns]

# %%
X = pd.concat([df['Age'], s_dum, dum_cp, df.loc[:, ['RestingBP','Cholesterol','FastingBS']], rest_dum, df['MaxHR'], ex_dum, df['Oldpeak'], st_dum],axis=1)
X
# Out:
#      Age      F      M    ASY    ATA    NAP     TA  RestingBP  Cholesterol  \
# 0     40  False   True  False   True  False  False        140          289
# 1     49   True  False  False  False   True  False        160          180
# 2     37  False   True  False   True  False  False        130          283
# 3     48   True  False   True  False  False  False        138          214
# 4     54  False   True  False  False   True  False        150          195
# ..   ...    ...    ...    ...    ...    ...    ...        ...          ...
# 913   45  False   True  False  False  False   True        110          264
# 914   68  False   True   True  False  False  False        144          193
# 915   57  False   True   True  False  False  False        130          131
# 916   57   True  False  False   True  False  False        130          236
# 917   38  False   True  False  False   True  False        138          175
#
# ...

# %%
y = df.HeartDisease
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %% [markdown]
# ## Alternative Way

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
mean_bp = df.RestingBP.mean()
df['RestingBP'] = df['RestingBP'].replace(0, mean_bp)
df['Cholesterol'] = df['Cholesterol'].replace(0, df.Cholesterol.mean())
df['FastingBS'] = df['FastingBS'].replace(0, df.FastingBS.mean())
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0        289.0   0.233115     Normal
# 1     49   F           NAP      160.0        180.0   0.233115     Normal
# 2     37   M           ATA      130.0        283.0   0.233115         ST
# 3     48   F           ASY      138.0        214.0   0.233115     Normal
# 4     54   M           NAP      150.0        195.0   0.233115     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA      110.0        264.0   0.233115     Normal
# 914   68   M           ASY      144.0        193.0   1.000000     Normal
# 915   57   M           ASY      130.0        131.0   0.233115     Normal
# 916   57   F           ATA      130.0        236.0   0.233115        LVH
# 917   38   M           NAP      138.0        175.0   0.233115     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df[df.RestingBP==0]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df = pd.get_dummies(df)
df
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40      140.0        289.0   0.233115    172      0.0             0
# 1     49      160.0        180.0   0.233115    156      1.0             1
# 2     37      130.0        283.0   0.233115     98      0.0             0
# 3     48      138.0        214.0   0.233115    108      1.5             1
# 4     54      150.0        195.0   0.233115    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45      110.0        264.0   0.233115    132      1.2             1
# 914   68      144.0        193.0   1.000000    141      3.4             1
# 915   57      130.0        131.0   0.233115    115      1.2             1
# 916   57      130.0        236.0   0.233115    174      0.0             1
# 917   38      138.0        175.0   0.233115    173      0.0             0
#
#      Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP  \
# ...

# %%
X = df.drop('HeartDisease',axis='columns')
y = df.HeartDisease
print(X)
print(y)
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_F  Sex_M  \
# 0     40      140.0        289.0   0.233115    172      0.0  False   True
# 1     49      160.0        180.0   0.233115    156      1.0   True  False
# 2     37      130.0        283.0   0.233115     98      0.0  False   True
# 3     48      138.0        214.0   0.233115    108      1.5   True  False
# 4     54      150.0        195.0   0.233115    122      0.0  False   True
# ..   ...        ...          ...        ...    ...      ...    ...    ...
# 913   45      110.0        264.0   0.233115    132      1.2  False   True
# 914   68      144.0        193.0   1.000000    141      3.4  False   True
# 915   57      130.0        131.0   0.233115    115      1.2  False   True
# 916   57      130.0        236.0   0.233115    174      0.0   True  False
# 917   38      138.0        175.0   0.233115    173      0.0  False   True
#
#      ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# ...

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print('X train samples : ', X_train.shape)
print('y train samples : ' ,y_train.shape)
print('X test samples : ',X_test.shape)
print('y test samples : ',y_test.shape)
# Out:
# X train samples :  (734, 20)
# y train samples :  (734,)
# X test samples :  (184, 20)
# y test samples :  (184,)

# %% [markdown]
# ## Before PCA :

# %%
rf = cross_val_score(RandomForestClassifier(n_estimators=35), X_train, y_train)
print('Accuracies across each K-fold : ', rf)
# Out:
# Accuracies across each K-fold :  [0.89795918 0.86394558 0.88435374 0.87755102 0.78767123]

# %%
print('Mean of rf  : ', rf.mean())
print('Std of rf: ', rf.std())
# Out:
# Mean of rf  :  0.8622961513372471
# Std of rf:  0.03889138530251503

# %%
lr =  cross_val_score(LogisticRegression(max_iter=5000), X_train,y_train)
lr
# Out:
# array([0.89795918, 0.85034014, 0.86394558, 0.89115646, 0.78082192])

# %%
print('Mean of lr  : ', lr.mean())
print('Std of lr: ', lr.std())
# Out:
# Mean of lr  :  0.8568446556704874
# Std of lr:  0.04180883412719039

# %%
model = KNeighborsClassifier(n_neighbors=9)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
model.score(X_test, y_test)
# Out:
# 0.6847826086956522

# %%
knn_scores = cross_val_score(KNeighborsClassifier(n_neighbors=9), X_train, y_train)
print('Mean of knn: ', knn_scores.mean())
print('Std of knn: ', knn_scores.std())
# Out:
# Mean of knn:  0.6811014816885658
# Std of knn:  0.044388609487970375

# %% [markdown]
# ## After PCA

# %% [markdown]
# ## Normalize the Feature Matrix (X) with Standard Scaling

# %%
scalar = StandardScaler()
scaled_x = scalar.fit_transform(X)
print('scaled_x shape  : ', scaled_x.shape)
# Out:
# scaled_x shape  :  (918, 20)

# %%
pca = PCA(0.95)
x_pca = pca.fit_transform(scaled_x)
print('x_pca shape : ', x_pca.shape)
# Out:
# x_pca shape :  (918, 13)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_pca, y, test_size=0.2)

# %%
model = KNeighborsClassifier(n_neighbors=9)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8260869565217391

# %%
rf = cross_val_score(RandomForestClassifier(n_estimators=35),X_train, y_train)

print('Accuracies across each K-fold : ', rf)
print('Mean of rf  : ', rf.mean())
print('Std of rf: ', rf.std())
# Out:
# Accuracies across each K-fold :  [0.81632653 0.83673469 0.89795918 0.83673469 0.88356164]
# Mean of rf  :  0.8542633491752865
# Std of rf:  0.031052941046782995

# %%
lr = cross_val_score(LogisticRegression(max_iter=35),X_train, y_train)

print('Accuracies across each K-fold : ', lr)
print('Mean of lr : ', lr.mean())
print('Std of lr : ', lr.std())
# Out:
# Accuracies across each K-fold :  [0.82312925 0.85034014 0.89795918 0.83673469 0.87671233]
# Mean of rf  :  0.8569751188146493
# Std of rf:  0.027086865996712436

# %%
knn = cross_val_score(KNeighborsClassifier(n_neighbors=9),X_train, y_train)

print('Accuracies across each K-fold : ', knn)
print('Mean of knn  : ', knn.mean())
print('Std of knn : ', knn.std())
# Out:
# Accuracies across each K-fold :  [0.81632653 0.86394558 0.89795918 0.85714286 0.87671233]
# Mean of knn  :  0.8624172956853975
# Std of knn :  0.02691500602664598

# %% [markdown]
# ## Try retaining less variance using PCA and determine how it makes a difference.

# %%
pca = PCA(0.80)
pca_x = pca.fit_transform(scaled_x)
print('shape of pca_x : ', pca_x.shape)
# Out:
# shape of pca_x :  (918, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(pca_x, y, test_size=0.2)

# %%
model = KNeighborsClassifier(n_neighbors=9)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8478260869565217

# %%
rf = cross_val_score(RandomForestClassifier(n_estimators=35),X_train, y_train)

print('Accuracies across each K-fold : ', rf)
print('Mean of rf  : ', rf.mean())
print('Std of rf: ', rf.std())
# Out:
# Accuracies across each K-fold :  [0.8707483  0.81632653 0.80952381 0.8707483  0.85616438]
# Mean of rf  :  0.8447022644674307
# Std of rf:  0.026573964706926224

# %%
lr = cross_val_score(LogisticRegression(max_iter=35),X_train, y_train)

print('Accuracies across each K-fold : ', lr)
print('Mean of lr : ', lr.mean())
print('Std of lr : ', lr.std())
# Out:
# Accuracies across each K-fold :  [0.85034014 0.82312925 0.82312925 0.88435374 0.85616438]
# Mean of lr :  0.847423352902805
# Std of lr :  0.022931086101879567

# %%
knn = cross_val_score(KNeighborsClassifier(n_neighbors=9),X_train, y_train)

print('Accuracies across each K-fold : ', knn)
print('Mean of knn  : ', knn.mean())
print('Std of knn : ', knn.std())
# Out:
# Accuracies across each K-fold :  [0.84353741 0.78231293 0.83673469 0.8707483  0.85616438]
# Mean of knn  :  0.8378995433789955
# Std of knn :  0.030118631270524127
